# %% [markdown]
# # Dactylology — ASL Alphabet Model Training
#
# Train an MLP classifier on MediaPipe hand landmarks from the Kaggle ASL Alphabet dataset.
#
# **Two workflows:**
# 1. **Download pre-trained model** (Cell 3) — skip training, just get the model
# 2. **Train from scratch** (Cells 4-9) — download dataset, extract landmarks, train, export

# %%
# Cell 1 — Imports
import os, sys, subprocess, tarfile, urllib.request, datetime
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import mediapipe as mp
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

print(f"TensorFlow {tf.__version__}, MediaPipe {mp.__version__}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781770265.565583       7 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781770271.277492       7 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       6 from tensorflow import keras
#       7 from tensorflow.keras import layers
#       8 import mediapipe as mp
#       9 import cv2
# ---> 10 from sklearn.model_selection import train_test_split
#      11 from sklearn.preprocessing import LabelEncoder
#      12
#      13 print(f"TensorFlow {tf.__version__}, MediaPipe {mp.__version__}")
#
# ...

# %%
# Cell 2 — TensorBoard setup
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_cb = keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
print(f"TensorBoard log dir: {log_dir}")
print('Run: %tensorboard --logdir logs/fit  (in a new cell)')

# %% [markdown]
# ---
# ## Option 1: Download Pre-trained Model

# %%
# Cell 3 — Download pre-trained model (or skip to train from scratch)
MODEL_DIR = "client/public/model"
os.makedirs(MODEL_DIR, exist_ok=True)

URL = "https://huggingface.co/dactylology/asl-alphabet/resolve/main/model.tar.gz"
ARCHIVE = "/tmp/asl-model.tar.gz"

print("Downloading pre-trained model...")
urllib.request.urlretrieve(URL, ARCHIVE)
with tarfile.open(ARCHIVE) as tf:
    tf.extractall(MODEL_DIR)
print(f"Done. Model files in {MODEL_DIR}/")
print("If you want to train your own, skip this cell and continue from Cell 4.")

# %% [markdown]
# ---
# ## Option 2: Train from Scratch

# %% [markdown]
# ### Kaggle Dataset Setup
# 1. Download your `kaggle.json` from https://www.kaggle.com/settings → API
# 2. Upload it: drag into Jupyter file browser or run:
#    ```python
#    import json; k = json.loads(input("Paste kaggle.json contents: "))
#    os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)
#    json.dump(k, open(os.path.expanduser("~/.kaggle/kaggle.json"), "w"))
#    os.chmod(os.path.expanduser("~/.kaggle/kaggle.json"), 0o600)
#    ```

# %%
# Cell 4 — Download Kaggle ASL Alphabet dataset
# !kaggle datasets download -d grassknoted/asl-alphabet --unzip -p asl_alphabet_train 2>&1
print("Extracted to ./asl_alphabet_train/")

# %%
# Cell 5 — Extract MediaPipe hand landmarks
DATA_DIR = "asl_alphabet_train"

mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=True, max_num_hands=1,
                       min_detection_confidence=0.5)

def extract_landmarks(image_path: str):
    img = cv2.imread(image_path)
    if img is None: return None
    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    result = hands.process(rgb)
    if not result.multi_hand_landmarks: return None
    lm = result.multi_hand_landmarks[0]
    wrist = lm.landmark[0]
    return np.array([
        (p.x - wrist.x, p.y - wrist.y, p.z - wrist.z)
        for p in lm.landmark
    ], dtype=np.float32).flatten()

X, y = [], []
classes = sorted(os.listdir(DATA_DIR))
total = sum(len(files) for _, _, files in os.walk(DATA_DIR))

processed = 0
for cls in classes:
    cls_dir = os.path.join(DATA_DIR, cls)
    if not os.path.isdir(cls_dir): continue
    for fname in os.listdir(cls_dir):
        if not fname.lower().endswith((".jpg", ".jpeg", ".png")): continue
        feats = extract_landmarks(os.path.join(cls_dir, fname))
        if feats is not None:
            X.append(feats)
            y.append(cls)
        processed += 1
        if processed % 1000 == 0:
            print(f"  Processed {processed}/{total}")

X = np.array(X)
y = np.array(y)
print(f"Extracted {len(X)} samples with {X.shape[1]} features")
print(f"Classes: {sorted(set(y))}")

# %%
# Cell 6 — Train/test split & label encoding
le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)
print(f"Train: {len(X_train)}, Test: {len(X_test)}")

# %%
# Cell 7 — Build & train model
model = keras.Sequential([
    layers.Input(shape=(63,)),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(64, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(26, activation="softmax"),
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.summary()

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    batch_size=32,
    callbacks=[tensorboard_cb],
)

# %%
# Cell 8 — Evaluate & plot
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(history.history["accuracy"], label="train")
ax1.plot(history.history["val_accuracy"], label="val")
ax1.set(title="Accuracy", ylabel="accuracy", xlabel="epoch")
ax1.legend()
ax2.plot(history.history["loss"], label="train")
ax2.plot(history.history["val_loss"], label="val")
ax2.set(title="Loss", ylabel="loss", xlabel="epoch")
ax2.legend()
plt.show()

# %%
# Cell 9 — Export to TensorFlow.js
output_dir = "client/public/model"
os.makedirs(output_dir, exist_ok=True)
model.save("asl_model.h5")
print("Saved Keras model to asl_model.h5")

subprocess.run([
    "tensorflowjs_converter",
    "--input_format=keras",
    "asl_model.h5",
    output_dir,
], check=True)
print(f"TF.js model exported to {output_dir}/")
print("Reload the client app to use the new model.")
